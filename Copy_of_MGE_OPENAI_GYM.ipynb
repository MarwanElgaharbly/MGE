# %% [markdown]
# <a href="https://colab.research.google.com/github/MarwanElgaharbly/MGE/blob/master/Copy_of_MGE_OPENAI_GYM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INSTALL ROS MELODIC**

# %%
# !sudo sh -c 'echo "deb http://packages.ros.org/ros/ubuntu $(lsb_release -sc) main" > /etc/apt/sources.list.d/ros-latest.list'
# !sudo apt-key adv --keyserver 'hkp://keyserver.ubuntu.com:80' --recv-key \C1CF6E31E6BADE8868B172B4F42ED6FBAB17C654
# !sudo apt update

# %% [markdown]
# **INSTALL ROS MELODIC CONTINUED**

# %%
# !sudo apt install ros-melodic-desktop-full
# !sudo rosdep init
# !rosdep update
# !echo "source /opt/ros/melodic/setup.bash" >> ~/.bashrc
# !source ~/.bashrc
# !sudo apt install python-rosinstall python-rosinstall-generator python-wstool build-essential
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev avahi-daemon bind9-host
#   binfmt-support cython debhelper default-libmysqlclient-dev dh-autoreconf
#   dh-strip-nondeterminism docutils-common docutils-doc file fltk1.3-doc fluid
#   fonts-dejavu-core fonts-lato fonts-lyx gazebo9 gazebo9-common
#   gazebo9-plugin-base geoclue-2.0 geoip-database gettext gettext-base
#   gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0
#   gir1.2-pango-1.0 google-mock googletest gstreamer1.0-plugins-base hddtemp
#   iio-sensor-proxy intltool-debian javascript-common libapr1 libapr1-dev
#   libaprutil1 libaprutil1-dev libarchive-cpio-perl libarchive-zip-perl
# ...

# %% [markdown]
# **FIX BROKEN PACKAGES**

# %%
# !apt --fix-broken install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 87 not upgraded.

# %% [markdown]
# **OPENAI**

# %%
# !sudo apt update
# !sudo apt install golang libcupti-dev libjpeg-turbo8-dev make tmux htop chromium-browser git cmake zlib1g-dev libjpeg-dev xvfb ffmpeg xorg-dev python-opengl libboost-all-dev libsdl2-dev swig
# !cd
# !git clone https://github.com/openai/gym.git
# !cd gym
# !pip install -e gym
# !pip install -e 'gym[atari]'
# !pip install -e 'gym[box2d]'
# !pip install -e 'gym[classic_control]'
# !pip install pybullet

# %% [markdown]
# **TENSORFLOW**

# %%
# !pip install tensorflow

# %% [markdown]
# **CATKIN WORKSPACE**

# %%
# !source /opt/ros/melodic/setup.bash

# %%
# !mkdir -p /content/catkin_ws/src
# !cd /content/catkin_ws
# !ls
#!catkin_make
#!source devel/setup.bash
# Out:
# content  src

# %% [markdown]
# **OR**

# %%
# !mkdir -p ~/catkin_ws/src
# %cd ~/catkin_ws
#!cd
# !catkin_make
# !source devel/setup.bash

# %% [markdown]
# **OPENAI_ROS CONT'D**

# %%
# !pip install gitpython
# !cd ~/catkin_ws/src
# !git clone https://bitbucket.org/theconstructcore/openai_ros.git
# !cd openai_ros
# !git checkout version2
# !cd ~/catkin_ws
# !catkin_make
# !source devel/setup.bash
# !rosdep install openai_ros
# Out:
# ...
# Cloning into 'openai_ros'...
# remote: Counting objects: 2273, done.
# remote: Compressing objects: 100% (639/639), done.
# remote: Total 2273 (delta 1458), reused 2176 (delta 1382)
# Receiving objects: 100% (2273/2273), 5.15 MiB | 10.95 MiB/s, done.
# Resolving deltas: 100% (1458/1458), done.
# fatal: not a git repository (or any of the parent directories): .git
# /bin/bash: catkin_make: command not found
# /bin/bash: devel/setup.bash: No such file or directory
# WARNING: ROS_PYTHON_VERSION is unset. Defaulting to 2
#
# ERROR: Rosdep cannot find all required resources to answer your query
# Missing resource openai_ros

# %%
# !source /opt/ros/melodic/setup.bash
# !roscd rospy
# Out:
# /bin/bash: roscd: command not found
